# %%
import pandas as pd
import numpy as np

# %%
ben = pd.read_excel("ben.xlsx")

# %%
ben.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        30 non-null     int64
#  1   customer_name      30 non-null     object
#  2   email              30 non-null     object
#  3   phone              30 non-null     int64
#  4   city               30 non-null     object
#  5   country            30 non-null     object
#  6   registration_date  30 non-null     datetime64[ns]
#  7   birth_date         30 non-null     datetime64[ns]
#  8   gender             30 non-null     object
# dtypes: datetime64[ns](2), int64(2), object(5)
# memory usage: 2.2+ KB

# %%
ben.isnull().sum()
# Out:
# customer_id          0
# customer_name        0
# email                0
# phone                0
# city                 0
# country              0
# registration_date    0
# birth_date           0
# gender               0
# dtype: int64

# %%
from datetime import datetime
today=pd.Timestamp.today().normalize()
today
# Out:
# Timestamp('2026-01-05 00:00:00')

# %%
ben['customer_Tenure']=(today-ben['registration_date']).dt.days//30

# %%
ben['age']=(today-ben['birth_date']).dt.days//365

# %%
ben['tenure_segment']=pd.cut(ben['customer_Tenure'],bins=[0,6,24,float('inf')],labels=['new','regular','loyal'])

# %%
ben['tenure_segment'].value_counts()
# Out:
# tenure_segment
# loyal      18
# regular     9
# new         2
# Name: count, dtype: int64

# %%
ben
# Out:
#     customer_id   customer_name                     email         phone  \
# 0             1     Ayse Yıldız            Ayse@gmail.com  905578910927
# 1             2      John Smith           Johns@yahoo.com  447392128544
# 2             3        Elif Can       canElif@hotmail.com  901234526234
# 3             4     Michael Lee      michaellee@gmail.com  495678972313
# 4             5       Bengü Ada           bengü@gmail.com  905678931130
# 5             6    Maral Calgın         maral@hotmail.com  905982343683
# 6             7     Petek Polat           petek@yahoo.com  902345243956
# 7             8     Sena Dilder    senadilber@hotmail.com  902345789082
# 8             9      Ela Sondur            elaa@gmail.com  902356894654
# 9            10  Zeynep Sürmeli       zeynepsür@gmail.com  901246764543
# 10           11     Esra Kochan       esrakoc@hotmail.com  903456776543
# 11           12    Dilara Aydın        dilaraaa@gmail.com  902456787654
# ...
